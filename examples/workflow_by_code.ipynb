# %% [markdown]
# <a href="https://colab.research.google.com/github/microsoft/qlib/blob/main/examples/workflow_by_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Copyright (c) Microsoft Corporation.
#  Licensed under the MIT License.

# %%
import sys, site
from pathlib import Path

################################# NOTE #################################
#  Please be aware that if colab installs the latest numpy and pyqlib  #
#  in this cell, users should RESTART the runtime in order to run the  #
#  following cells successfully.                                       #
########################################################################

try:
    import qlib
except ImportError:
    # install qlib
    ! pip install --upgrade numpy
    ! pip install pyqlib
    if "google.colab" in sys.modules:
        # The Google colab environment is a little outdated. We have to downgrade the pyyaml to make it compatible with other packages
        ! pip install pyyaml==5.4.1
    # reload
    site.main()

scripts_dir = Path.cwd().parent.joinpath("scripts")
if not scripts_dir.joinpath("get_data.py").exists():
    # download get_data.py script
    scripts_dir = Path("~/tmp/qlib_code/scripts").expanduser().resolve()
    scripts_dir.mkdir(parents=True, exist_ok=True)
    import requests

    with requests.get("https://raw.githubusercontent.com/microsoft/qlib/main/scripts/get_data.py", timeout=10) as resp:
        with open(scripts_dir.joinpath("get_data.py"), "wb") as fp:
            fp.write(resp.content)
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.3.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Downloading numpy-2.3.0-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.3.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.0 which is incompatible.
# langchain 0.0.226 requires numpy<2,>=1, but you have numpy 2.3.0 which is incompatible.
# langchain 0.0.226 requires pydantic<2,>=1, but you have pydantic 2.11.5 which is incompatible.
# Successfully installed numpy-2.3.0
# Collecting pyqlib
#   Downloading pyqlib-0.9.6-cp311-cp311-macosx_10_9_universal2.whl.metadata (43 kB)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (6.0.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (2.3.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (2.3.0)
# Collecting mlflow (from pyqlib)
#   Downloading mlflow-3.1.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: filelock>=3.16.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (3.18.0)
# Collecting redis (from pyqlib)
#   Downloading redis-6.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: dill in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (0.3.8)
# Collecting fire (from pyqlib)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml>=0.17.38 (from pyqlib)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Collecting python-redis-lock (from pyqlib)
#   Downloading python_redis_lock-4.0.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (4.67.1)
# Collecting pymongo (from pyqlib)
#   Downloading pymongo-4.13.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (22 kB)
# Requirement already satisfied: loguru in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (0.7.3)
# Collecting lightgbm (from pyqlib)
#   Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Collecting gym (from pyqlib)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 1.8 MB/s eta 0:00:00m-:--:--
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cvxpy (from pyqlib)
#   Downloading cvxpy-1.6.6-cp311-cp311-macosx_10_9_universal2.whl.metadata (9.3 kB)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (1.5.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pyqlib) (3.10.3)
# Collecting jupyter (from pyqlib)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting nbconvert (from pyqlib)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.38->pyqlib)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl.metadata (2.7 kB)
# Collecting osqp>=0.6.2 (from cvxpy->pyqlib)
#   Downloading osqp-1.0.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy->pyqlib)
#   Downloading clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy->pyqlib)
#   Downloading scs-3.2.7.post2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: scipy>=1.11.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from cvxpy->pyqlib) (1.15.3)
# Requirement already satisfied: cffi in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from clarabel>=0.5.0->cvxpy->pyqlib) (1.17.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy->pyqlib) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy->pyqlib) (79.0.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from cffi->clarabel>=0.5.0->cvxpy->pyqlib) (2.22)
# Requirement already satisfied: termcolor in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from fire->pyqlib) (3.1.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from gym->pyqlib) (3.1.1)
# Collecting gym_notices>=0.0.4 (from gym->pyqlib)
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jinja2->osqp>=0.6.2->cvxpy->pyqlib) (3.0.2)
# Collecting notebook (from jupyter->pyqlib)
#   Downloading notebook-7.4.3-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->pyqlib)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter->pyqlib) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter->pyqlib) (8.0.6)
# Collecting jupyterlab (from jupyter->pyqlib)
#   Downloading jupyterlab-4.4.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (1.6.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (25.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipykernel->jupyter->pyqlib) (5.14.3)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (2.19.1)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyqlib) (4.13.2)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->pyqlib) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->pyqlib) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter->pyqlib) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipywidgets->jupyter->pyqlib) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from ipywidgets->jupyter->pyqlib) (3.0.15)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->pyqlib)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyterlab->jupyter->pyqlib) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->pyqlib)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->pyqlib)
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->pyqlib)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->pyqlib)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib) (4.9.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib) (0.22.1)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (4.24.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->pyqlib) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->pyqlib) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->pyqlib) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (0.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib) (3.3.0)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting beautifulsoup4 (from nbconvert->pyqlib)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->pyqlib)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->pyqlib)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->pyqlib)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->pyqlib)
#   Downloading mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->pyqlib)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->pyqlib)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->pyqlib)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->pyqlib)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyqlib) (2.4.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->pyqlib)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyqlib)
#   Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from matplotlib->pyqlib) (3.2.3)
# Collecting mlflow-skinny==3.1.0 (from mlflow->pyqlib)
#   Downloading mlflow_skinny-3.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting Flask<4 (from mlflow->pyqlib)
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow->pyqlib)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow->pyqlib)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->pyqlib)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow->pyqlib)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow->pyqlib) (20.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow->pyqlib) (1.6.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow->pyqlib) (2.0.41)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (6.0.0)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (8.2.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Downloading databricks_sdk-0.57.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: fastapi<1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (0.115.12)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (1.34.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (1.34.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (5.29.5)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (2.11.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from mlflow-skinny==3.1.0->mlflow->pyqlib) (0.34.3)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->pyqlib)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.1.0->mlflow->pyqlib) (0.46.2)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow->pyqlib)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow->pyqlib)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from Flask<4->mlflow->pyqlib) (3.1.3)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->pyqlib)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->pyqlib)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.0->mlflow->pyqlib) (3.22.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.0->mlflow->pyqlib) (0.55b0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pandas->pyqlib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pandas->pyqlib) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow->pyqlib) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow->pyqlib) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.1.0->mlflow->pyqlib) (0.4.1)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.0->mlflow->pyqlib)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from scikit-learn<2->mlflow->pyqlib) (3.6.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from pymongo->pyqlib) (2.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/py311_torch/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyqlib) (0.2.3)
# Downloading pyqlib-0.9.6-cp311-cp311-macosx_10_9_universal2.whl (951 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.0/952.0 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-macosx_13_0_arm64.whl (132 kB)
# Downloading cvxpy-1.6.6-cp311-cp311-macosx_10_9_universal2.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.1/935.1 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading osqp-1.0.4-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
# Downloading scs-3.2.7.post2-cp311-cp311-macosx_11_0_arm64.whl (93 kB)
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.4.3-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 7.4 MB/s eta 0:00:00 0:00:01
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading mlflow-3.1.0-py3-none-any.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Downloading mlflow_skinny-3.1.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.8 MB/s eta 0:00:00a 0:00:01
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
# Downloading databricks_sdk-0.57.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 9.4 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading notebook-7.4.3-py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 7.1 MB/s eta 0:00:00a 0:00:01
# Downloading pymongo-4.13.1-cp311-cp311-macosx_11_0_arm64.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 6.9 MB/s eta 0:00:00
# Downloading python_redis_lock-4.0.0-py3-none-any.whl (12 kB)
# Downloading redis-6.2.0-py3-none-any.whl (278 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: fire, gym
#   DEPRECATION: Building 'fire' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fire'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114332 sha256=506b431bc6fd7841b1341941a0067eb49bd59a9193aa4bc9d941be5fab445e30
#   Stored in directory: /Users/fan/Library/Caches/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827727 sha256=7e84355021424081e6d6391fcea21a28ce791c6641fb1adac4a806b7162c1cbb
#   Stored in directory: /Users/fan/Library/Caches/pip/wheels/1c/77/9e/9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built fire gym
# Installing collected packages: webencodings, gym_notices, fastjsonschema, websocket-client, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, sqlparse, soupsieve, smmap, send2trash, ruamel.yaml.clib, rfc3986-validator, rfc3339-validator, redis, pymongo, pyasn1, pandocfilters, overrides, mistune, Mako, jupyterlab-pygments, jsonpointer, json5, itsdangerous, gym, gunicorn, graphql-core, fqdn, fire, defusedxml, cachetools, blinker, bleach, babel, async-lru, scs, ruamel.yaml, rsa, python-redis-lock, pyasn1-modules, osqp, lightgbm, jupyter-server-terminals, graphql-relay, gitdb, Flask, docker, clarabel, beautifulsoup4, arrow, argon2-cffi-bindings, alembic, isoduration, graphene, google-auth, gitpython, cvxpy, argon2-cffi, nbformat, jupyter-console, databricks-sdk, nbclient, mlflow-skinny, jupyter-events, nbconvert, mlflow, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, pyqlib
#   Attempting uninstall: cachetools━━━━━━━━━━━━━━━━━━━━━━━ 31/77 [fire]ql-core]
#     Found existing installation: cachetools 6.0.0━━━━━━━━━━━━━ 31/77 [fire]
#     Uninstalling cachetools-6.0.0:━━━━━━━━━━━━━━━━━━━━━━━ 31/77 [fire]
#       Successfully uninstalled cachetools-6.0.0━━━━━━━━━━━━━━━ 31/77 [fire]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77/77 [pyqlib] [pyqlib] [notebook]b]ver]
# Successfully installed Flask-3.1.1 Mako-1.3.10 alembic-1.16.1 argon2-cffi-25.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 babel-2.17.0 beautifulsoup4-4.13.4 bleach-6.2.0 blinker-1.9.0 cachetools-5.5.2 clarabel-0.11.1 cvxpy-1.6.6 databricks-sdk-0.57.0 defusedxml-0.7.1 docker-7.1.0 fastjsonschema-2.21.1 fire-0.7.0 fqdn-1.5.1 gitdb-4.0.12 gitpython-3.1.44 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 gym-0.26.2 gym_notices-0.0.8 isoduration-20.11.0 itsdangerous-2.2.0 json5-0.12.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.3 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 lightgbm-4.6.0 mistune-3.1.3 mlflow-3.1.0 mlflow-skinny-3.1.0 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.3 notebook-shim-0.2.4 osqp-1.0.4 overrides-7.7.0 pandocfilters-1.5.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pymongo-4.13.1 pyqlib-0.9.6 python-redis-lock-4.0.0 redis-6.2.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rsa-4.9.1 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 scs-3.2.7.post2 send2trash-1.8.3 smmap-5.0.2 soupsieve-2.7 sqlparse-0.5.3 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20250516 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0

# %%
import qlib
import pandas as pd
from qlib.constant import REG_CN
from qlib.utils import exists_qlib_data, init_instance_by_config
from qlib.workflow import R
from qlib.workflow.record_temp import SignalRecord, PortAnaRecord
from qlib.utils import flatten_dict

# %%
# use default data
# NOTE: need to download data from remote: python scripts/get_data.py qlib_data_cn --target_dir ~/.qlib/qlib_data/cn_data
provider_uri = "~/.qlib/qlib_data/cn_data"  # target_dir
if not exists_qlib_data(provider_uri):
    print(f"Qlib data is not found in {provider_uri}")
    sys.path.append(str(scripts_dir))
    from get_data import GetData

    GetData().qlib_data(target_dir=provider_uri, region=REG_CN)
qlib.init(provider_uri=provider_uri, region=REG_CN)
# Out:
# Qlib data is not found in ~/.qlib/qlib_data/cn_data
# 2025-06-14 01:41:38.882 | WARNING  | qlib.tests.data:download:62 - The data for the example is collected from Yahoo Finance. Please be aware that the quality of the data might not be perfect. (You can refer to the original data source: https://finance.yahoo.com/lookup.)
# 2025-06-14 01:41:38.883 | INFO     | qlib.tests.data:download:65 - 20250614014136_qlib_data_cn_1d_latest.zip downloading......
#   0%|          | 0/196549189 [00:00<?, ?it/s]2025-06-14 01:41:38.883 | INFO     | qlib.tests.data:download:65 - 20250614014136_qlib_data_cn_1d_latest.zip downloading......
# 196549632it [01:06, 2963909.55it/s]
# 2025-06-14 01:42:45.211 | WARNING  | qlib.tests.data:_unzip:124 - will delete the old qlib data directory(features, instruments, calendars, features_cache, dataset_cache): /Users/fan/.qlib/qlib_data/cn_data
# 2025-06-14 01:42:45.212 | INFO     | qlib.tests.data:_unzip:128 - /Users/fan/.qlib/qlib_data/cn_data/20250614014136_qlib_data_cn_1d_latest.zip unzipping......
# 100%|██████████| 31008/31008 [00:05<00:00, 5785.69it/s]
# [35627:MainThread](2025-06-14 01:42:50,739) INFO - qlib.Initialization - [config.py:420] - default_conf: client.
# [35627:MainThread](2025-06-14 01:42:50,741) INFO - qlib.Initialization - [__init__.py:74] - qlib successfully initialized based on client settings.
# [35627:MainThread](2025-06-14 01:42:50,742) INFO - qlib.Initialization - [__init__.py:76] - data_path={'__DEFAULT_FREQ': PosixPath('/Users/fan/.qlib/qlib_data/cn_data')}

# %%
market = "csi300"
benchmark = "SH000300"

# %% [markdown]
# # train model

# %%
###################################
# train model
###################################
data_handler_config = {
    "start_time": "2008-01-01",
    "end_time": "2020-08-01",
    "fit_start_time": "2008-01-01",
    "fit_end_time": "2014-12-31",
    "instruments": market,
}

task = {
    "model": {
        "class": "LGBModel",
        "module_path": "qlib.contrib.model.gbdt",
        "kwargs": {
            "loss": "mse",
            "colsample_bytree": 0.8879,
            "learning_rate": 0.0421,
            "subsample": 0.8789,
            "lambda_l1": 205.6999,
            "lambda_l2": 580.9768,
            "max_depth": 8,
            "num_leaves": 210,
            "num_threads": 20,
        },
    },
    "dataset": {
        "class": "DatasetH",
        "module_path": "qlib.data.dataset",
        "kwargs": {
            "handler": {
                "class": "Alpha158",
                "module_path": "qlib.contrib.data.handler",
                "kwargs": data_handler_config,
            },
            "segments": {
                "train": ("2008-01-01", "2014-12-31"),
                "valid": ("2015-01-01", "2016-12-31"),
                "test": ("2017-01-01", "2020-08-01"),
            },
        },
    },
}

# model initialization
model = init_instance_by_config(task["model"])
dataset = init_instance_by_config(task["dataset"])

# start exp to train model
with R.start(experiment_name="train_model"):
    R.log_params(**flatten_dict(task))
    model.fit(dataset)
    R.save_objects(trained_model=model)
    rid = R.get_recorder().id
# Out:
# ModuleNotFoundError. CatBoostModel are skipped. (optional: maybe installing CatBoostModel can fix it.)
# ModuleNotFoundError. XGBModel is skipped(optional: maybe installing xgboost can fix it).
# ModuleNotFoundError.  PyTorch models are skipped (optional: maybe installing pytorch can fix it).
# [33472:MainThread](2025-05-30 23:43:00,252) INFO - qlib.timer - [log.py:127] - Time cost: 65.258s | Loading data Done
# [33472:MainThread](2025-05-30 23:43:02,030) INFO - qlib.timer - [log.py:127] - Time cost: 0.558s | DropnaLabel Done
# [33472:MainThread](2025-05-30 23:43:04,959) INFO - qlib.timer - [log.py:127] - Time cost: 2.928s | CSZScoreNorm Done
# [33472:MainThread](2025-05-30 23:43:05,005) INFO - qlib.timer - [log.py:127] - Time cost: 4.751s | fit & process data Done
# [33472:MainThread](2025-05-30 23:43:05,006) INFO - qlib.timer - [log.py:127] - Time cost: 70.012s | Init data Done
# [33472:MainThread](2025-05-30 23:43:05,024) WARNING - qlib.workflow - [expm.py:231] - No valid experiment found. Create a new experiment with name train_model.
# [33472:MainThread](2025-05-30 23:43:05,030) INFO - qlib.workflow - [exp.py:258] - Experiment 273733318884080872 starts running ...
# [33472:MainThread](2025-05-30 23:43:05,221) INFO - qlib.workflow - [recorder.py:345] - Recorder 25fe78515c914ae39cc00aca189b12b6 starts running under Experiment 273733318884080872 ...
# Training until validation scores don't improve for 50 rounds
# [20]	train's l2: 0.990585	valid's l2: 0.994309
# [40]	train's l2: 0.986931	valid's l2: 0.993693
# [60]	train's l2: 0.984352	valid's l2: 0.99349
# [80]	train's l2: 0.982319	valid's l2: 0.993382
# [100]	train's l2: 0.980442	valid's l2: 0.99331
# [120]	train's l2: 0.97871	valid's l2: 0.993247
# [140]	train's l2: 0.976987	valid's l2: 0.993334
# [160]	train's l2: 0.97536	valid's l2: 0.993338
# Early stopping, best iteration is:
# [122]	train's l2: 0.978519	valid's l2: 0.993238
# [33472:MainThread](2025-05-30 23:43:27,818) INFO - qlib.timer - [log.py:127] - Time cost: 0.373s | waiting `async_log` Done

# %% [markdown]
# # prediction, backtest & analysis

# %%
###################################
# prediction, backtest & analysis
###################################
port_analysis_config = {
    "executor": {
        "class": "SimulatorExecutor",
        "module_path": "qlib.backtest.executor",
        "kwargs": {
            "time_per_step": "day",
            "generate_portfolio_metrics": True,
        },
    },
    "strategy": {
        "class": "TopkDropoutStrategy",
        "module_path": "qlib.contrib.strategy.signal_strategy",
        "kwargs": {
            "model": model,
            "dataset": dataset,
            "topk": 50,
            "n_drop": 5,
        },
    },
    "backtest": {
        "start_time": "2017-01-01",
        "end_time": "2020-08-01",
        "account": 100000000,
        "benchmark": benchmark,
        "exchange_kwargs": {
            "freq": "day",
            "limit_threshold": 0.095,
            "deal_price": "close",
            "open_cost": 0.0005,
            "close_cost": 0.0015,
            "min_cost": 5,
        },
    },
}

# backtest and analysis
with R.start(experiment_name="backtest_analysis"):
    recorder = R.get_recorder(recorder_id=rid, experiment_name="train_model")
    model = recorder.load_object("trained_model")

    # prediction
    recorder = R.get_recorder()
    ba_rid = recorder.id
    sr = SignalRecord(model, dataset, recorder)
    sr.generate()

    # backtest & analysis
    par = PortAnaRecord(recorder, port_analysis_config, "day")
    par.generate()
# Out:
# [33472:MainThread](2025-05-30 23:43:58,785) WARNING - qlib.workflow - [expm.py:231] - No valid experiment found. Create a new experiment with name backtest_analysis.
# [33472:MainThread](2025-05-30 23:43:58,792) INFO - qlib.workflow - [exp.py:258] - Experiment 737731714663440462 starts running ...
# [33472:MainThread](2025-05-30 23:43:58,818) INFO - qlib.workflow - [recorder.py:345] - Recorder c73b9c93875347d99b9014d22559f1e5 starts running under Experiment 737731714663440462 ...
# [33472:MainThread](2025-05-30 23:44:00,203) INFO - qlib.workflow - [record_temp.py:198] - Signal record 'pred.pkl' has been saved as the artifact of the Experiment 737731714663440462
# [33472:MainThread](2025-05-30 23:44:00,279) INFO - qlib.backtest caller - [__init__.py:93] - Create new exchange
# 'The following are prediction results of the LGBModel model.'
#                           score
# datetime   instrument
# 2017-01-03 SH600000   -0.042865
#            SH600008    0.005925
#            SH600009    0.030596
#            SH600010   -0.013973
#            SH600015   -0.141758
# [33472:MainThread](2025-05-30 23:44:23,506) WARNING - qlib.online operator - [exchange.py:219] - $close field data contains nan.
# [33472:MainThread](2025-05-30 23:44:23,509) WARNING - qlib.online operator - [exchange.py:219] - $close field data contains nan.
# [33472:MainThread](2025-05-30 23:44:23,526) WARNING - qlib.online operator - [exchange.py:226] - factor.day.bin file not exists or factor contains `nan`. Order using adjusted_price.
# [33472:MainThread](2025-05-30 23:44:23,528) WARNING - qlib.online operator - [exchange.py:228] - trade unit 100 is not supported in adjusted_price mode.
# [33472:MainThread](2025-05-30 23:44:49,144) WARNING - qlib.data - [data.py:665] - load calendar error: freq=day, future=True; return current calendar!
# [33472:MainThread](2025-05-30 23:44:49,146) WARNING - qlib.data - [data.py:668] - You can get future calendar by referring to the following document: https://github.com/microsoft/qlib/blob/main/scripts/data_collector/contrib/README.md
# [33472:MainThread](2025-05-30 23:44:49,169) WARNING - qlib.BaseExecutor - [executor.py:121] - `common_infra` is not set for <qlib.backtest.executor.SimulatorExecutor object at 0x164484b50>
# backtest loop:   0%|          | 0/871 [00:00<?, ?it/s]
# /opt/anaconda3/envs/py311_tf218/lib/python3.11/site-packages/qlib/utils/index_data.py:492: RuntimeWarning: Mean of empty slice
#   return np.nanmean(self.data)
# /opt/anaconda3/envs/py311_tf218/lib/python3.11/site-packages/qlib/utils/index_data.py:492: RuntimeWarning: Mean of empty slice
#   return np.nanmean(self.data)
# /opt/anaconda3/envs/py311_tf218/lib/python3.11/site-packages/qlib/utils/index_data.py:492: RuntimeWarning: Mean of empty slice
#   return np.nanmean(self.data)
# [33472:MainThread](2025-05-30 23:45:03,067) INFO - qlib.workflow - [record_temp.py:515] - Portfolio analysis record 'port_analysis_1day.pkl' has been saved as the artifact of the Experiment 737731714663440462
# [33472:MainThread](2025-05-30 23:45:03,074) INFO - qlib.workflow - [record_temp.py:540] - Indicator analysis record 'indicator_analysis_1day.pkl' has been saved as the artifact of the Experiment 737731714663440462
# 'The following are analysis results of benchmark return(1day).'
#                        risk
# mean               0.000477
# std                0.012295
# annualized_return  0.113561
# information_ratio  0.598699
# max_drawdown      -0.370479
# 'The following are analysis results of the excess return without cost(1day).'
#                        risk
# mean               0.000730
# std                0.005705
# annualized_return  0.173708
# information_ratio  1.973639
# max_drawdown      -0.057265
# 'The following are analysis results of the excess return with cost(1day).'
#                        risk
# mean               0.000535
# std                0.005703
# annualized_return  0.127230
# information_ratio  1.446068
# max_drawdown      -0.066180
# 'The following are analysis results of indicators(1day).'
#      value
# ffr    1.0
# pa     0.0
# pos    0.0
# [33472:MainThread](2025-05-30 23:45:04,023) INFO - qlib.timer - [log.py:127] - Time cost: 0.000s | waiting `async_log` Done

# %% [markdown]
# # analyze graphs

# %%
from qlib.contrib.report import analysis_model, analysis_position
from qlib.data import D

recorder = R.get_recorder(recorder_id=ba_rid, experiment_name="backtest_analysis")
print(recorder)
pred_df = recorder.load_object("pred.pkl")
report_normal_df = recorder.load_object("portfolio_analysis/report_normal_1day.pkl")
positions = recorder.load_object("portfolio_analysis/positions_normal_1day.pkl")
analysis_df = recorder.load_object("portfolio_analysis/port_analysis_1day.pkl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from qlib.contrib.report import analysis_model, analysis_position
#       2 from qlib.data import D
#       4 recorder = R.get_recorder(recorder_id=ba_rid, experiment_name="backtest_analysis")
#
# File /opt/anaconda3/envs/py311_tf218/lib/python3.11/site-packages/qlib/contrib/report/analysis_model/__init__.py:4
#       1 # Copyright (c) Microsoft Corporation.
#       2 # Licensed under the MIT License.
# ----> 4 from .analysis_model_performance import model_performance_graph
#       7 __all__ = ["model_performance_graph"]
#
# File /opt/anaconda3/envs/py311_tf218/lib/python3.11/site-packages/qlib/contrib/report/analysis_model/analysis_model_performance.py:7
#       3 from functools import partial
#       5 import pandas as pd
# ----> 7 import plotly.graph_objs as go
#       9 import statsmodels.api as sm
#      10 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ## analysis position

# %% [markdown]
# ### report

# %%
analysis_position.report_graph(report_normal_df)

# %% [markdown]
# ### risk analysis

# %%
analysis_position.risk_analysis_graph(analysis_df, report_normal_df)

# %% [markdown]
# ## analysis model

# %%
label_df = dataset.prepare("test", col_set="label")
label_df.columns = ["label"]

# %% [markdown]
# ### score IC

# %%
pred_label = pd.concat([label_df, pred_df], axis=1, sort=True).reindex(label_df.index)
analysis_position.score_ic_graph(pred_label)

# %% [markdown]
# ### model performance

# %%
analysis_model.model_performance_graph(pred_label)
